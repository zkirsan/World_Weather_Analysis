# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longtitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs= zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longtitudes to a list.
coordinates = list(lats_lngs)

# %%
# Use the citipy module to determine city based on latitude and longtitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longtitude combination.
for coordinate in coordinates:
    city= citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d4944b089b43886e2e2dfe10a629be2

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
     # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
    
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
# if an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
    pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | mathbaria
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | cherskiy
# Processing Record 5 of Set 1 | havelock
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | lata
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | guerrero negro
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | hambantota
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | geraldton
# Processing Record 17 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | muros
# Processing Record 21 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | frolishchi
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | yeppoon
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | joshimath
# Processing Record 28 of Set 1 | povorino
# Processing Record 29 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 1 | rudnyy
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | tarakan
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | caravelas
# Processing Record 38 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 1 | carutapera
# Processing Record 40 of Set 1 | beringovskiy
# Processing Record 41 of Set 1 | harur
# Processing Record 42 of Set 1 | maceio
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | kungurtug
# Processing Record 45 of Set 1 | norman wells
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | cacheu
# Processing Record 48 of Set 1 | zlocieniec
# Processing Record 49 of Set 1 | severo-kurilsk
# Processing Record 50 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 2 | asau
# Processing Record 2 of Set 2 | lorengau
# Processing Record 3 of Set 2 | santa cruz del sur
# Processing Record 4 of Set 2 | san cristobal
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | annau
# Processing Record 8 of Set 2 | pisco
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | bondo
# Processing Record 11 of Set 2 | muborak
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | mogadishu
# Processing Record 17 of Set 2 | faanui
# Processing Record 18 of Set 2 | shimoda
# Processing Record 19 of Set 2 | mandalgovi
# Processing Record 20 of Set 2 | hami
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | karratha
# Processing Record 23 of Set 2 | gambela
# Processing Record 24 of Set 2 | pevek
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | saint-pierre
# Processing Record 27 of Set 2 | talnakh
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | kirs
# Processing Record 30 of Set 2 | dongsheng
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | fortuna
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | potsdam
# Processing Record 37 of Set 2 | san estanislao
# Processing Record 38 of Set 2 | christchurch
# Processing Record 39 of Set 2 | elat
# Processing Record 40 of Set 2 | palafrugell
# Processing Record 41 of Set 2 | cidreira
# Processing Record 42 of Set 2 | baft
# Processing Record 43 of Set 2 | kokoda
# Processing Record 44 of Set 2 | virginia beach
# Processing Record 45 of Set 2 | kaitangata
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | katsuura
# Processing Record 50 of Set 2 | ajaccio
# Processing Record 1 of Set 3 | nemuro
# Processing Record 2 of Set 3 | saskylakh
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 3 | beyla
# Processing Record 6 of Set 3 | korla
# Processing Record 7 of Set 3 | bulgan
# Processing Record 8 of Set 3 | leningradskiy
# Processing Record 9 of Set 3 | atar
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | hervey bay
# Processing Record 12 of Set 3 | ayorou
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | bluff
# Processing Record 15 of Set 3 | buraydah
# Processing Record 16 of Set 3 | massakory
# Processing Record 17 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 18 of Set 3 | beeville
# Processing Record 19 of Set 3 | maniitsoq
# Processing Record 20 of Set 3 | abbeville
# Processing Record 21 of Set 3 | port alfred
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | jamsa
# Processing Record 24 of Set 3 | camacha
# Processing Record 25 of Set 3 | sept-iles
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | sao filipe
# Processing Record 28 of Set 3 | mackay
# Processing Record 29 of Set 3 | manggar
# Processing Record 30 of Set 3 | labuhan
# Processing Record 31 of Set 3 | tetlanohcan
# Processing Record 32 of Set 3 | muzaffarabad
# Processing Record 33 of Set 3 | paita
# Processing Record 34 of Set 3 | camargo
# Processing Record 35 of Set 3 | airai
# Processing Record 36 of Set 3 | port maria
# Processing Record 37 of Set 3 | lagoa
# Processing Record 38 of Set 3 | isla vista
# Processing Record 39 of Set 3 | gurgan
# City not found. Skipping...
# Processing Record 40 of Set 3 | ilulissat
# Processing Record 41 of Set 3 | akersberga
# Processing Record 42 of Set 3 | srednekolymsk
# Processing Record 43 of Set 3 | hasaki
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | shu
# Processing Record 46 of Set 3 | mahebourg
# Processing Record 47 of Set 3 | hibbing
# Processing Record 48 of Set 3 | stanislav
# Processing Record 49 of Set 3 | constitucion
# Processing Record 50 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 4 | busselton
# Processing Record 2 of Set 4 | lebu
# Processing Record 3 of Set 4 | huilong
# Processing Record 4 of Set 4 | moron
# Processing Record 5 of Set 4 | umba
# Processing Record 6 of Set 4 | camabatela
# Processing Record 7 of Set 4 | bengkulu
# Processing Record 8 of Set 4 | assiniboia
# Processing Record 9 of Set 4 | prince rupert
# Processing Record 10 of Set 4 | codrington
# Processing Record 11 of Set 4 | hay river
# Processing Record 12 of Set 4 | tipuani
# Processing Record 13 of Set 4 | kahului
# Processing Record 14 of Set 4 | tuktoyaktuk
# Processing Record 15 of Set 4 | khatanga
# Processing Record 16 of Set 4 | denpasar
# Processing Record 17 of Set 4 | juegang
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 4 | bereda
# Processing Record 21 of Set 4 | suihua
# Processing Record 22 of Set 4 | vardo
# Processing Record 23 of Set 4 | northam
# Processing Record 24 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 4 | kudahuvadhoo
# Processing Record 26 of Set 4 | avarua
# Processing Record 27 of Set 4 | tefe
# Processing Record 28 of Set 4 | winslow
# Processing Record 29 of Set 4 | ryotsu
# Processing Record 30 of Set 4 | ponta do sol
# Processing Record 31 of Set 4 | elk plain
# Processing Record 32 of Set 4 | chuy
# Processing Record 33 of Set 4 | wanlaweyn
# Processing Record 34 of Set 4 | quelimane
# Processing Record 35 of Set 4 | murgab
# Processing Record 36 of Set 4 | kodinsk
# Processing Record 37 of Set 4 | sorkjosen
# Processing Record 38 of Set 4 | dunedin
# Processing Record 39 of Set 4 | flores
# Processing Record 40 of Set 4 | narsaq
# Processing Record 41 of Set 4 | torbay
# Processing Record 42 of Set 4 | verkhnevilyuysk
# Processing Record 43 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 4 | lixourion
# Processing Record 45 of Set 4 | qaqortoq
# Processing Record 46 of Set 4 | pimentel
# Processing Record 47 of Set 4 | sovetskaya
# Processing Record 48 of Set 4 | coquimbo
# Processing Record 49 of Set 4 | skagen
# Processing Record 50 of Set 4 | san quintin
# Processing Record 1 of Set 5 | nouadhibou
# Processing Record 2 of Set 5 | bara
# Processing Record 3 of Set 5 | yangmei
# Processing Record 4 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 5 | vestmannaeyjar
# Processing Record 6 of Set 5 | sao miguel do araguaia
# Processing Record 7 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 5 | nago
# Processing Record 9 of Set 5 | yulara
# Processing Record 10 of Set 5 | deyang
# Processing Record 11 of Set 5 | yakeshi
# Processing Record 12 of Set 5 | saldanha
# Processing Record 13 of Set 5 | saumur
# Processing Record 14 of Set 5 | ginir
# Processing Record 15 of Set 5 | tura
# Processing Record 16 of Set 5 | the valley
# Processing Record 17 of Set 5 | san patricio
# Processing Record 18 of Set 5 | datong
# Processing Record 19 of Set 5 | altamira
# Processing Record 20 of Set 5 | wanning
# Processing Record 21 of Set 5 | cururupu
# Processing Record 22 of Set 5 | jizan
# Processing Record 23 of Set 5 | touros
# Processing Record 24 of Set 5 | klamath falls
# Processing Record 25 of Set 5 | beyneu
# Processing Record 26 of Set 5 | narasannapeta
# Processing Record 27 of Set 5 | cheremukhovo
# Processing Record 28 of Set 5 | chachapoyas
# Processing Record 29 of Set 5 | nanortalik
# Processing Record 30 of Set 5 | sergeyevka
# Processing Record 31 of Set 5 | birjand
# Processing Record 32 of Set 5 | bafata
# Processing Record 33 of Set 5 | tessalit
# Processing Record 34 of Set 5 | longyearbyen
# Processing Record 35 of Set 5 | boyolangu
# Processing Record 36 of Set 5 | alice springs
# Processing Record 37 of Set 5 | los llanos de aridane
# Processing Record 38 of Set 5 | bhadrachalam
# Processing Record 39 of Set 5 | lufilufi
# Processing Record 40 of Set 5 | sambava
# Processing Record 41 of Set 5 | bose
# Processing Record 42 of Set 5 | opunake
# Processing Record 43 of Set 5 | hamilton
# Processing Record 44 of Set 5 | kavaratti
# Processing Record 45 of Set 5 | carhuamayo
# Processing Record 46 of Set 5 | homer
# Processing Record 47 of Set 5 | nabire
# Processing Record 48 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 5 | margate
# Processing Record 50 of Set 5 | wanaka
# Processing Record 1 of Set 6 | mabaruma
# Processing Record 2 of Set 6 | sao joao da barra
# Processing Record 3 of Set 6 | lompoc
# Processing Record 4 of Set 6 | panama city
# Processing Record 5 of Set 6 | burnie
# Processing Record 6 of Set 6 | kazanskaya
# Processing Record 7 of Set 6 | kamennogorsk
# Processing Record 8 of Set 6 | bonthe
# Processing Record 9 of Set 6 | praia da vitoria
# Processing Record 10 of Set 6 | wukari
# Processing Record 11 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | esperance
# Processing Record 13 of Set 6 | inta
# Processing Record 14 of Set 6 | estevan
# Processing Record 15 of Set 6 | tailai
# Processing Record 16 of Set 6 | college
# Processing Record 17 of Set 6 | sokolo
# Processing Record 18 of Set 6 | nizhnevartovsk
# Processing Record 19 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 6 | kamina
# Processing Record 21 of Set 6 | vao
# Processing Record 22 of Set 6 | tokat
# Processing Record 23 of Set 6 | kutum
# Processing Record 24 of Set 6 | aripuana
# Processing Record 25 of Set 6 | lar
# Processing Record 26 of Set 6 | half moon bay
# Processing Record 27 of Set 6 | tazovskiy
# Processing Record 28 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 6 | tieli
# Processing Record 30 of Set 6 | mount gambier
# Processing Record 31 of Set 6 | nikolayevsk-na-amure
# Processing Record 32 of Set 6 | tiksi
# Processing Record 33 of Set 6 | amboasary
# Processing Record 34 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 6 | tulagi
# Processing Record 36 of Set 6 | nome
# Processing Record 37 of Set 6 | cintalapa
# Processing Record 38 of Set 6 | menongue
# Processing Record 39 of Set 6 | dali
# Processing Record 40 of Set 6 | sayyan
# Processing Record 41 of Set 6 | cabedelo
# Processing Record 42 of Set 6 | chicama
# Processing Record 43 of Set 6 | eskil
# Processing Record 44 of Set 6 | ola
# Processing Record 45 of Set 6 | ternate
# Processing Record 46 of Set 6 | kendari
# Processing Record 47 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 6 | chirala
# Processing Record 49 of Set 6 | kargasok
# Processing Record 50 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 7 | huangchuan
# Processing Record 2 of Set 7 | hirado
# Processing Record 3 of Set 7 | selty
# Processing Record 4 of Set 7 | komsomolskiy
# Processing Record 5 of Set 7 | port augusta
# Processing Record 6 of Set 7 | gewane
# Processing Record 7 of Set 7 | sao gabriel da cachoeira
# Processing Record 8 of Set 7 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 9 of Set 7 | colesberg
# Processing Record 10 of Set 7 | kanniyakumari
# Processing Record 11 of Set 7 | deputatskiy
# Processing Record 12 of Set 7 | noumea
# Processing Record 13 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 15 of Set 7 | sydney
# Processing Record 16 of Set 7 | saint-philippe
# Processing Record 17 of Set 7 | nioro
# Processing Record 18 of Set 7 | tiznit
# Processing Record 19 of Set 7 | muzhi
# Processing Record 20 of Set 7 | ushtobe
# Processing Record 21 of Set 7 | hoyanger
# Processing Record 22 of Set 7 | souillac
# Processing Record 23 of Set 7 | tshikapa
# Processing Record 24 of Set 7 | lavrentiya
# Processing Record 25 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 7 | gazojak
# Processing Record 27 of Set 7 | namatanai
# Processing Record 28 of Set 7 | andenes
# Processing Record 29 of Set 7 | hohhot
# Processing Record 30 of Set 7 | kavieng
# Processing Record 31 of Set 7 | fernie
# Processing Record 32 of Set 7 | japura
# Processing Record 33 of Set 7 | baruun-urt
# Processing Record 34 of Set 7 | asyut
# Processing Record 35 of Set 7 | yumen
# Processing Record 36 of Set 7 | griffith
# Processing Record 37 of Set 7 | port keats
# Processing Record 38 of Set 7 | kyzyl-suu
# Processing Record 39 of Set 7 | bonfim
# Processing Record 40 of Set 7 | vieques
# Processing Record 41 of Set 7 | richards bay
# Processing Record 42 of Set 7 | port hardy
# Processing Record 43 of Set 7 | jalalabad
# Processing Record 44 of Set 7 | grand gaube
# Processing Record 45 of Set 7 | nioki
# Processing Record 46 of Set 7 | marquette
# Processing Record 47 of Set 7 | bougouni
# Processing Record 48 of Set 7 | lerwick
# Processing Record 49 of Set 7 | solnechnyy
# Processing Record 50 of Set 7 | biak
# Processing Record 1 of Set 8 | comodoro rivadavia
# Processing Record 2 of Set 8 | nizwa
# Processing Record 3 of Set 8 | coracao de jesus
# Processing Record 4 of Set 8 | luderitz
# Processing Record 5 of Set 8 | natitingou
# Processing Record 6 of Set 8 | morondava
# Processing Record 7 of Set 8 | arlit
# Processing Record 8 of Set 8 | zima
# Processing Record 9 of Set 8 | ancud
# Processing Record 10 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 11 of Set 8 | sakaiminato
# Processing Record 12 of Set 8 | seryshevo
# Processing Record 13 of Set 8 | shieli
# Processing Record 14 of Set 8 | fomboni
# Processing Record 15 of Set 8 | khandyga
# Processing Record 16 of Set 8 | vila velha
# Processing Record 17 of Set 8 | darlowo
# Processing Record 18 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 8 | tabou
# Processing Record 20 of Set 8 | te anau
# Processing Record 21 of Set 8 | mount isa
# Processing Record 22 of Set 8 | batticaloa
# Processing Record 23 of Set 8 | villanueva
# Processing Record 24 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 8 | tautira
# Processing Record 26 of Set 8 | axim
# Processing Record 27 of Set 8 | bassar
# Processing Record 28 of Set 8 | sinnamary
# Processing Record 29 of Set 8 | anadyr
# Processing Record 30 of Set 8 | cairns
# Processing Record 31 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 8 | puerto penasco
# Processing Record 33 of Set 8 | catumbela
# Processing Record 34 of Set 8 | salalah
# Processing Record 35 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 8 | pangai
# Processing Record 37 of Set 8 | kidal
# Processing Record 38 of Set 8 | fairbanks
# Processing Record 39 of Set 8 | huarmey
# Processing Record 40 of Set 8 | tilichiki
# Processing Record 41 of Set 8 | agadez
# Processing Record 42 of Set 8 | walvis bay
# Processing Record 43 of Set 8 | raga
# Processing Record 44 of Set 8 | gopalpur
# Processing Record 45 of Set 8 | adrar
# Processing Record 46 of Set 8 | veraval
# Processing Record 47 of Set 8 | kirando
# Processing Record 48 of Set 8 | abnub
# Processing Record 49 of Set 8 | turukhansk
# Processing Record 50 of Set 8 | vostok
# Processing Record 1 of Set 9 | thunder bay
# Processing Record 2 of Set 9 | agadir
# Processing Record 3 of Set 9 | tulu bolo
# Processing Record 4 of Set 9 | egvekinot
# Processing Record 5 of Set 9 | okha
# Processing Record 6 of Set 9 | pishin
# Processing Record 7 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 9 | morgan city
# Processing Record 9 of Set 9 | atascadero
# Processing Record 10 of Set 9 | castro
# Processing Record 11 of Set 9 | tromso
# Processing Record 12 of Set 9 | saint-augustin
# Processing Record 13 of Set 9 | tual
# Processing Record 14 of Set 9 | vernon
# Processing Record 15 of Set 9 | nizhneangarsk
# Processing Record 16 of Set 9 | kaiyuan
# Processing Record 17 of Set 9 | zhigansk
# Processing Record 18 of Set 9 | jibuti
# Processing Record 19 of Set 9 | bandarbeyla
# Processing Record 20 of Set 9 | karak
# Processing Record 21 of Set 9 | pontal do parana
# Processing Record 22 of Set 9 | creel
# Processing Record 23 of Set 9 | salinopolis
# Processing Record 24 of Set 9 | bam
# Processing Record 25 of Set 9 | palmer
# Processing Record 26 of Set 9 | salinas
# Processing Record 27 of Set 9 | bergen
# Processing Record 28 of Set 9 | lima
# Processing Record 29 of Set 9 | san jose
# Processing Record 30 of Set 9 | hofn
# Processing Record 31 of Set 9 | berlevag
# Processing Record 32 of Set 9 | rocha
# Processing Record 33 of Set 9 | sitka
# Processing Record 34 of Set 9 | ivanovka
# Processing Record 35 of Set 9 | chiredzi
# Processing Record 36 of Set 9 | booue
# Processing Record 37 of Set 9 | jabinyanah
# Processing Record 38 of Set 9 | kontagora
# Processing Record 39 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 40 of Set 9 | erding
# Processing Record 41 of Set 9 | dudinka
# Processing Record 42 of Set 9 | imbituba
# Processing Record 43 of Set 9 | sur
# Processing Record 44 of Set 9 | bambanglipuro
# Processing Record 45 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 46 of Set 9 | san antonio
# Processing Record 47 of Set 9 | iringa
# Processing Record 48 of Set 9 | kanzaki
# Processing Record 49 of Set 9 | ust-omchug
# Processing Record 50 of Set 9 | ustyuzhna
# Processing Record 1 of Set 10 | nyurba
# Processing Record 2 of Set 10 | tuatapere
# Processing Record 3 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 10 | manavgat
# Processing Record 5 of Set 10 | bay saint louis
# Processing Record 6 of Set 10 | mushie
# Processing Record 7 of Set 10 | manbij
# Processing Record 8 of Set 10 | luwuk
# Processing Record 9 of Set 10 | mapiripan
# Processing Record 10 of Set 10 | faya
# Processing Record 11 of Set 10 | quatre cocos
# Processing Record 12 of Set 10 | ballina
# Processing Record 13 of Set 10 | mangrol
# Processing Record 14 of Set 10 | qiqihar
# Processing Record 15 of Set 10 | groningen
# Processing Record 16 of Set 10 | riverton
# Processing Record 17 of Set 10 | jiwani
# Processing Record 18 of Set 10 | matagami
# Processing Record 19 of Set 10 | la rioja
# Processing Record 20 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 21 of Set 10 | pinawa
# Processing Record 22 of Set 10 | sibolga
# Processing Record 23 of Set 10 | grindavik
# Processing Record 24 of Set 10 | bontang
# Processing Record 25 of Set 10 | clyde river
# Processing Record 26 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 10 | corinto
# Processing Record 28 of Set 10 | aguimes
# Processing Record 29 of Set 10 | aktash
# Processing Record 30 of Set 10 | pavia
# Processing Record 31 of Set 10 | eureka
# Processing Record 32 of Set 10 | port alberni
# Processing Record 33 of Set 10 | vila franca do campo
# Processing Record 34 of Set 10 | acapulco
# Processing Record 35 of Set 10 | zhanaozen
# Processing Record 36 of Set 10 | gharb
# City not found. Skipping...
# Processing Record 37 of Set 10 | jacqueville
# Processing Record 38 of Set 10 | xam nua
# Processing Record 39 of Set 10 | shizunai
# Processing Record 40 of Set 10 | palu
# Processing Record 41 of Set 10 | milkovo
# Processing Record 42 of Set 10 | peniche
# Processing Record 43 of Set 10 | ixtapa
# Processing Record 44 of Set 10 | sangar
# Processing Record 45 of Set 10 | crateus
# Processing Record 46 of Set 10 | itaituba
# Processing Record 47 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 10 | tucumcari
# Processing Record 50 of Set 10 | xingyi
# Processing Record 1 of Set 11 | alanya
# Processing Record 2 of Set 11 | evanston
# Processing Record 3 of Set 11 | kuroiso
# Processing Record 4 of Set 11 | basmat
# Processing Record 5 of Set 11 | portland
# Processing Record 6 of Set 11 | chapada dos guimaraes
# Processing Record 7 of Set 11 | haines junction
# Processing Record 8 of Set 11 | semporna
# Processing Record 9 of Set 11 | kafue
# Processing Record 10 of Set 11 | terra boa
# Processing Record 11 of Set 11 | pangnirtung
# Processing Record 12 of Set 11 | ossora
# Processing Record 13 of Set 11 | pasighat
# Processing Record 14 of Set 11 | phumi samraong
# City not found. Skipping...
# Processing Record 15 of Set 11 | moose factory
# Processing Record 16 of Set 11 | sao jose da coroa grande
# Processing Record 17 of Set 11 | banda aceh
# Processing Record 18 of Set 11 | den helder
# Processing Record 19 of Set 11 | fagernes
# Processing Record 20 of Set 11 | dhidhdhoo
# Processing Record 21 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 11 | marilia
# Processing Record 23 of Set 11 | broken hill
# Processing Record 24 of Set 11 | mehamn
# Processing Record 25 of Set 11 | hoi an
# Processing Record 26 of Set 11 | lardos
# Processing Record 27 of Set 11 | la asuncion
# Processing Record 28 of Set 11 | eirunepe
# Processing Record 29 of Set 11 | mitsamiouli
# Processing Record 30 of Set 11 | stryn
# Processing Record 31 of Set 11 | isangel
# Processing Record 32 of Set 11 | teguise
# Processing Record 33 of Set 11 | meiktila
# Processing Record 34 of Set 11 | punta alta
# Processing Record 35 of Set 11 | port hedland
# Processing Record 36 of Set 11 | yar-sale
# Processing Record 37 of Set 11 | san juan
# Processing Record 38 of Set 11 | cockburn town
# Processing Record 39 of Set 11 | troitskoye
# Processing Record 40 of Set 11 | riachao das neves
# Processing Record 41 of Set 11 | gizo
# Processing Record 42 of Set 11 | shar
# Processing Record 43 of Set 11 | jacareacanga
# Processing Record 44 of Set 11 | eidsvag
# Processing Record 45 of Set 11 | otane
# Processing Record 46 of Set 11 | dingle
# Processing Record 47 of Set 11 | pueblo
# Processing Record 48 of Set 11 | laguna
# Processing Record 49 of Set 11 | amapa
# Processing Record 50 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 1 of Set 12 | naze
# Processing Record 2 of Set 12 | coahuayana
# Processing Record 3 of Set 12 | buala
# Processing Record 4 of Set 12 | campoverde
# Processing Record 5 of Set 12 | port hawkesbury
# Processing Record 6 of Set 12 | sobrance
# Processing Record 7 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 8 of Set 12 | wiesmoor
# Processing Record 9 of Set 12 | port blair
# Processing Record 10 of Set 12 | belyy yar
# Processing Record 11 of Set 12 | ostrovnoy
# Processing Record 12 of Set 12 | trapani
# Processing Record 13 of Set 12 | ponta delgada
# Processing Record 14 of Set 12 | doaba
# Processing Record 15 of Set 12 | yerbogachen
# Processing Record 16 of Set 12 | alofi
# Processing Record 17 of Set 12 | teneguiban
# City not found. Skipping...
# Processing Record 18 of Set 12 | atherton
# Processing Record 19 of Set 12 | pacific grove
# Processing Record 20 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 12 | iralaya
# Processing Record 22 of Set 12 | kurumkan
# Processing Record 23 of Set 12 | chkalovsk
# Processing Record 24 of Set 12 | zephyrhills
# Processing Record 25 of Set 12 | varlamovo
# Processing Record 26 of Set 12 | ios
# Processing Record 27 of Set 12 | inhambane
# Processing Record 28 of Set 12 | storsteinnes
# Processing Record 29 of Set 12 | chapayevka
# Processing Record 30 of Set 12 | coos bay
# Processing Record 31 of Set 12 | taft
# Processing Record 32 of Set 12 | catamarca
# Processing Record 33 of Set 12 | fort nelson
# Processing Record 34 of Set 12 | cabo san lucas
# Processing Record 35 of Set 12 | xudat
# Processing Record 36 of Set 12 | sheridan
# Processing Record 37 of Set 12 | svetlyy
# Processing Record 38 of Set 12 | laranjeiras do sul
# Processing Record 39 of Set 12 | havre-saint-pierre
# Processing Record 40 of Set 12 | shelburne
# Processing Record 41 of Set 12 | holme
# Processing Record 42 of Set 12 | westport
# Processing Record 43 of Set 12 | port lincoln
# Processing Record 44 of Set 12 | paredon
# Processing Record 45 of Set 12 | abha
# Processing Record 46 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 12 | borama
# City not found. Skipping...
# Processing Record 48 of Set 12 | bud
# Processing Record 49 of Set 12 | lichinga
# Processing Record 50 of Set 12 | piacabucu
# Processing Record 1 of Set 13 | belmonte
# Processing Record 2 of Set 13 | manokwari
# Processing Record 3 of Set 13 | porgera
# Processing Record 4 of Set 13 | bilma
# Processing Record 5 of Set 13 | khash
# Processing Record 6 of Set 13 | barda
# Processing Record 7 of Set 13 | tootsi
# Processing Record 8 of Set 13 | bako
# Processing Record 9 of Set 13 | taoudenni
# Processing Record 10 of Set 13 | mayo
# Processing Record 11 of Set 13 | pocone
# Processing Record 12 of Set 13 | plymouth
# Processing Record 13 of Set 13 | itajuba
# Processing Record 14 of Set 13 | marang
# Processing Record 15 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 16 of Set 13 | tomatlan
# Processing Record 17 of Set 13 | antalaha
# Processing Record 18 of Set 13 | smolenka
# Processing Record 19 of Set 13 | shenjiamen
# Processing Record 20 of Set 13 | labuan
# Processing Record 21 of Set 13 | belaya gora
# Processing Record 22 of Set 13 | hammerfest
# Processing Record 23 of Set 13 | teluknaga
# Processing Record 24 of Set 13 | alyangula
# Processing Record 25 of Set 13 | yarmouth
# Processing Record 26 of Set 13 | tiarei
# Processing Record 27 of Set 13 | miandrivazo
# Processing Record 28 of Set 13 | saint george
# Processing Record 29 of Set 13 | guasdualito
# Processing Record 30 of Set 13 | plettenberg bay
# Processing Record 31 of Set 13 | colares
# Processing Record 32 of Set 13 | washougal
# Processing Record 33 of Set 13 | greytown
# Processing Record 34 of Set 13 | tsubata
# Processing Record 35 of Set 13 | karaton
# Processing Record 36 of Set 13 | lagos
# Processing Record 37 of Set 13 | sakakah
# Processing Record 38 of Set 13 | el campo
# Processing Record 39 of Set 13 | anloga
# Processing Record 40 of Set 13 | toamasina
# Processing Record 41 of Set 13 | kukurecani
# Processing Record 42 of Set 13 | namibe
# Processing Record 43 of Set 13 | borba
# Processing Record 44 of Set 13 | areia branca
# Processing Record 45 of Set 13 | lebowakgomo
# Processing Record 46 of Set 13 | san pedro
# Processing Record 47 of Set 13 | conway
# Processing Record 48 of Set 13 | tlahualilo
# City not found. Skipping...
# Processing Record 49 of Set 13 | moengo
# Processing Record 50 of Set 13 | jinchengjiang
# City not found. Skipping...
# Processing Record 1 of Set 14 | lao cai
# Processing Record 2 of Set 14 | philadelphia
# Processing Record 3 of Set 14 | mortka
# Processing Record 4 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 14 | tagusao
# Processing Record 6 of Set 14 | aklavik
# Processing Record 7 of Set 14 | pak phanang
# Processing Record 8 of Set 14 | nakasongola
# Processing Record 9 of Set 14 | erenhot
# Processing Record 10 of Set 14 | vanimo
# Processing Record 11 of Set 14 | madera
# Processing Record 12 of Set 14 | dunhua
# Processing Record 13 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 14 | fort frances
# Processing Record 15 of Set 14 | pundri
# Processing Record 16 of Set 14 | reshetnikovo
# Processing Record 17 of Set 14 | lasa
# Processing Record 18 of Set 14 | malaya serdoba
# Processing Record 19 of Set 14 | chenzhou
# Processing Record 20 of Set 14 | canutama
# Processing Record 21 of Set 14 | hirara
# Processing Record 22 of Set 14 | aykhal
# Processing Record 23 of Set 14 | douentza
# Processing Record 24 of Set 14 | juneau
# Processing Record 25 of Set 14 | saint-joseph
# Processing Record 26 of Set 14 | nantucket
# Processing Record 27 of Set 14 | yulin
# Processing Record 28 of Set 14 | natal
# Processing Record 29 of Set 14 | mayahi
# Processing Record 30 of Set 14 | gornozavodsk
# Processing Record 31 of Set 14 | chapais
# Processing Record 32 of Set 14 | rayachoti
# Processing Record 33 of Set 14 | puerto escondido
# Processing Record 34 of Set 14 | boa vista
# Processing Record 35 of Set 14 | gwadar
# Processing Record 36 of Set 14 | rockport
# Processing Record 37 of Set 14 | saint-denis
# Processing Record 38 of Set 14 | williams lake
# Processing Record 39 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 14 | chai nat
# Processing Record 41 of Set 14 | anori
# Processing Record 42 of Set 14 | urengoy
# Processing Record 43 of Set 14 | brigantine
# Processing Record 44 of Set 14 | lomovka
# Processing Record 45 of Set 14 | kununurra
# Processing Record 46 of Set 14 | paamiut
# Processing Record 47 of Set 14 | taizhou
# Processing Record 48 of Set 14 | selma
# Processing Record 49 of Set 14 | husavik
# Processing Record 50 of Set 14 | marawi
# Processing Record 1 of Set 15 | karasuk
# Processing Record 2 of Set 15 | surt
# Processing Record 3 of Set 15 | necochea
# Processing Record 4 of Set 15 | laiyang
# Processing Record 5 of Set 15 | aktau
# Processing Record 6 of Set 15 | augusto correa
# Processing Record 7 of Set 15 | ugoofaaru
# Processing Record 8 of Set 15 | baghmara
# Processing Record 9 of Set 15 | bahia blanca
# Processing Record 10 of Set 15 | alcaniz
# Processing Record 11 of Set 15 | mocuba
# Processing Record 12 of Set 15 | gigmoto
# Processing Record 13 of Set 15 | mwinilunga
# Processing Record 14 of Set 15 | shingu
# Processing Record 15 of Set 15 | bathsheba
# Processing Record 16 of Set 15 | vanavara
# Processing Record 17 of Set 15 | saint-leu
# Processing Record 18 of Set 15 | north bend
# Processing Record 19 of Set 15 | sarahan
# Processing Record 20 of Set 15 | aksarka
# Processing Record 21 of Set 15 | sandviken
# Processing Record 22 of Set 15 | xuddur
# Processing Record 23 of Set 15 | orlik
# Processing Record 24 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 25 of Set 15 | mandiana
# Processing Record 26 of Set 15 | gueret
# Processing Record 27 of Set 15 | trincomalee
# Processing Record 28 of Set 15 | guajara-mirim
# City not found. Skipping...
# Processing Record 29 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 15 | tall kayf
# Processing Record 31 of Set 15 | kemijarvi
# Processing Record 32 of Set 15 | pemangkat
# Processing Record 33 of Set 15 | chipinge
# Processing Record 34 of Set 15 | dapaong
# Processing Record 35 of Set 15 | sarangani
# Processing Record 36 of Set 15 | dawson creek
# Processing Record 37 of Set 15 | rincon
# Processing Record 38 of Set 15 | goderich
# Processing Record 39 of Set 15 | zheleznodorozhnyy
# Processing Record 40 of Set 15 | nebbi
# Processing Record 41 of Set 15 | zaozerne
# Processing Record 42 of Set 15 | korsakov
# Processing Record 43 of Set 15 | tambopata
# Processing Record 44 of Set 15 | owando
# Processing Record 45 of Set 15 | kaeo
# Processing Record 46 of Set 15 | kishorganj
# Processing Record 47 of Set 15 | aksay
# Processing Record 48 of Set 15 | zanjan
# Processing Record 49 of Set 15 | barranca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vaini -21.2000 -175.2000     80.60        74          20
# 1     Mathbaria  22.2876   89.9593     82.60        53           0
# 2  Punta Arenas -53.1500  -70.9167     39.20        75           0
# 3      Cherskiy  68.7500  161.3000      2.53        86          48
# 4      Havelock  34.8791  -76.9013     60.01        76           1
#
#    Wind Speed Country Current Description
# 0       11.50      TO          few clouds
# 1        2.48      BD           clear sky
# 2        6.91      CL           clear sky
# 3        3.44      RU    scattered clouds
# 4       10.36      US           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Vaini      TO -21.2000 -175.2000     80.60        74          20
# 1       Mathbaria      BD  22.2876   89.9593     82.60        53           0
# 2    Punta Arenas      CL -53.1500  -70.9167     39.20        75           0
# 3        Cherskiy      RU  68.7500  161.3000      2.53        86          48
# 4        Havelock      US  34.8791  -76.9013     60.01        76           1
# 5  Port Elizabeth      ZA -33.9180   25.5701     64.40        94          90
# 6       Jamestown      US  42.0970  -79.2353     44.60        53           1
# 7       Cape Town      ZA -33.9258   18.4232     64.00        88           0
# 8         Mataura      NZ -46.1927  168.8643     57.00        58         100
# 9            Lata      PT  40.1629   -8.3327     55.00        93          75
#
#    Wind Speed Current Description
# 0       11.50          few clouds
# 1        2.48           clear sky
# 2        6.91           clear sky
# 3        3.44    scattered clouds
# 4       10.36           clear sky
# 5       17.27          light rain
# 6        3.44           clear sky
# 7       10.36           clear sky
# 8       25.99     overcast clouds
# 9        3.44                mist

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
